# %% [markdown]
# Team Name: DataVortex_005_020_044_045
#
# Name 1: Abhishek Bhat - PES1UG22AM005
#
# Name 2: Anagha S Bharadwaj - PES1UG22AM020
#
# Name 3: C Hemachandra - PES1UG22AM044
#
# Name 4: Chaitra V - PES1UG22AM045

# %% [markdown]
# **Federated Learning-based Code:**
#
# Local Devices compute similarity scores on their subset of data and return encrypted results (encrypted indices and similarity scores).
#
# The central server decrypts the results, aggregates them, and returns the top similar statements to the user.

# %% [markdown]
# Modified the code to print both the encrypted and decrypted versions of the query and similar statements

# %%
import pandas as pd
from cryptography.fernet import Fernet
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Step 1: Generate encryption key and create Fernet instance
key = Fernet.generate_key()
cipher_suite = Fernet(key)

# Step 2: Load dataset (modify the file path as needed)
file_path = 'D:/SEMESTER 5/Algorithms and Optimizations in Machine Learning (AOML)/AOML_Project/Reviews.csv/Reviews.csv'
df = pd.read_csv(file_path)

# Ensure relevant columns exist
if 'Text' not in df.columns:
    raise ValueError("The dataset must contain a 'Text' column.")

# Truncate long text entries to reduce memory usage
df['Text'] = df['Text'].apply(lambda x: x[:500] if isinstance(x, str) else x)

# Function to encrypt text
def encrypt(text):
    return cipher_suite.encrypt(text.encode()).decode()

# Function to decrypt text
def decrypt(encrypted_text):
    return cipher_suite.decrypt(encrypted_text.encode()).decode()

# Simulate a federated local device
def local_device_search(query, dataset_texts, device_id, top_n=5):
    # Local device computes similarity scores (without sending raw data)
    print(f"\nDevice {device_id} is computing similarity scores locally...")
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(dataset_texts)
    query_vector = vectorizer.transform([query])
    similarity_scores = cosine_similarity(query_vector, tfidf_matrix).flatten()

    # Local device returns top N encrypted similarity scores (no raw data)
    top_indices = similarity_scores.argsort()[-top_n:][::-1]
    encrypted_top_indices = [encrypt(str(i)) for i in top_indices]
    encrypted_similarity_scores = [encrypt(str(similarity_scores[i])) for i in top_indices]

    return encrypted_top_indices, encrypted_similarity_scores

# Simulate the central server aggregating results from multiple devices
def central_server_aggregator(all_encrypted_top_indices, all_encrypted_similarity_scores, dataset_texts):
    print("\nCentral server aggregating encrypted results...")
    # Decrypt the received results
    decrypted_top_indices = [decrypt(index) for indices in all_encrypted_top_indices for index in indices]
    decrypted_similarity_scores = [decrypt(score) for scores in all_encrypted_similarity_scores for score in scores]

    # Aggregate and rank based on decrypted similarity scores
    decrypted_top_indices = list(map(int, decrypted_top_indices))
    decrypted_similarity_scores = list(map(float, decrypted_similarity_scores))

    # Sort the results by similarity score in descending order
    sorted_indices = np.argsort(decrypted_similarity_scores)[::-1]

    # Get the top N similar statements
    top_similar_statements = [dataset_texts[i] for i in sorted_indices]
    return top_similar_statements

# Full workflow (with Federated Learning simulation)
def privacy_preserving_workflow(dataset):
    # Take user input for the query
    query = input("Enter your query: ")
    print("\n1. Original Query:", query)

    # Encrypt the query
    encrypted_query = encrypt(query)
    print("\n2. Encrypted Query:", encrypted_query)

    # Decrypt the query
    decrypted_query = decrypt(encrypted_query)
    print("\n3. Decrypted Query:", decrypted_query)

    # Split the dataset into 'local devices' (simulated by subsets)
    num_devices = 3  # For example, simulate 3 devices
    dataset_texts = dataset['Text'].dropna().tolist()
    chunk_size = len(dataset_texts) // num_devices

    all_encrypted_top_indices = []
    all_encrypted_similarity_scores = []

    # Each local device computes similarity scores and returns encrypted results
    for device_id in range(num_devices):
        start_idx = device_id * chunk_size
        end_idx = (device_id + 1) * chunk_size if device_id != num_devices - 1 else len(dataset_texts)

        # Simulate local device computing similarity scores
        local_encrypted_top_indices, local_encrypted_similarity_scores = local_device_search(
            decrypted_query, dataset_texts[start_idx:end_idx], device_id + 1)

        all_encrypted_top_indices.append(local_encrypted_top_indices)
        all_encrypted_similarity_scores.append(local_encrypted_similarity_scores)

    # The central server aggregates results
    top_similar_statements = central_server_aggregator(all_encrypted_top_indices, all_encrypted_similarity_scores, dataset_texts)

    print("\n4. Similar Statements Found:")
    for i, stmt in enumerate(top_similar_statements, 1):
        # Encrypt and decrypt the similar statements
        encrypted_stmt = encrypt(stmt)
        decrypted_stmt = decrypt(encrypted_stmt)

        # Print both encrypted and decrypted versions of the similar statement
        print(f"{i}. Encrypted Similar Statement: {encrypted_stmt}")
        print(f"   Decrypted Similar Statement: {decrypted_stmt}")

# Run the workflow
privacy_preserving_workflow(df)
# Out:
# 1. Original Query: Tasty
#
# 2. Encrypted Query: gAAAAABnPd2kTYoKdClZk6yFQsm5SNx69NoPsumfIXm6ThHTeYrY1egUWl9MyrfgfBt5IXeyTZURsUDWxmRHjxIAHrt1fdnhpw==
#
# 3. Decrypted Query: Tasty
#
# Device 1 is computing similarity scores locally...
#
# Device 2 is computing similarity scores locally...
#
# Device 3 is computing similarity scores locally...
#
# Central server aggregating encrypted results...
#
# 4. Similar Statements Found:
# 1. Encrypted Similar Statement: gAAAAABnPd3KOGpvRdWOsgiSRPQhVaB9EkTyyTH8l22MozUVkDnl7OTPOcim1a0MyCzfKshbhBeAhoQvTCMEM3M8h74D2J-mcyZct03i2W-xJjpdrHHKR4X7K92SItSX_51duOMnxYU-s-eA66D8gOpivRLhI0mpcCX8_IhJ7qSSncP6hi36roltFB25Y5XZv2LQb1lMNJVgjzpVM-1nnScdZUap-4nAHtNsGCANOR8yHZ15jogtizR2un_PVEYlb6smNdL123IBGv2-2f1dvfI3UubTYl3XQn3W8w0JOEtmFT4pu3mYT6pgnryEis7ro5vs5Q4qyMS8gAa4VE72YkFPSCZPR2xk7CgHObrGDn9T535u_w-SsA0prVKBpjdzcVHSCPNjTFaRNuw079E4sOKjv1pag-VErCQIl2AQoRtsmgZkU4W1QecUp-qSqqfBrIgQ3HJyCPvI9yi3K-KY0t9eTJ1XkWE_OrxFzdz7xPmw319h5zE7h2V9nF_tkmQi3jSvpCsCJNvp5nbsVRWf9MnL8gDHIIdYywBk6IjoGjHdw6qJjG4DsbutsSJ0Z-vjMnGifYQ1OMQmGC8gDlTe60bO66I2ves_PRIqTjZS4ZV8boIuK5ggAVRie9QzfPFjMJQt3B-floKd
#    Decrypted Similar Statement: I got a wild hair for taffy and ordered this five pound bag. The taffy was all very enjoyable with many flavors: watermelon, root beer, melon, peppermint, grape, etc. My only complaint is there was a bit too much red/black licorice-flavored pieces (just not my particular favorites). Between me, my kids, and my husband, this lasted only two weeks! I would recommend this brand of taffy -- it was a delightful treat.
# 2. Encrypted Similar Statement: gAAAAABnPd3KfEyGm0U4gudTMa9OVcg1nBg4ZGclAuLRdETi9Dg7c_wdRDOZ4O_-V0XnSEqSJW0AosEEEM09O_Ox6kkbY1T-p1OB274nPNMUbn1tpR-dOwzZQ9P6aAfIilBiFJ3OKVKWwM79vHGvZNx4qriM02qcWrQ0MYPdqNmgx8qLdumU0mFqc55WGEmT_fFITDbsIFutJb-xt8d_pDG1Rx-UE82wUZqN38SQUpHLWLE6QN5SzKGK7BGeghT8-PkToDuqUTT4Ku1DobrZCZZ1mY2tFJ_LeMZ9iJ4M4dZddreTFoIa4Hoi2fEP5oePzUgfZ5zQoBTceR7Bbu_0gI6YUSH0jlBHx6nc07zDy3bKfRnHcjMxJv217bYTvyxSkqkCxCaL2CJi0-4-sXOISBxrWtX8aiggpKHO8j6i0K-VcAiT9k-sLG5DLKhiCoCYD6WyKwFlnhk7PlPajcavSDoUGKY8k5C3lbGx5MIs-U4xMQZBc42UNsI=
#    Decrypted Similar Statement: This saltwater taffy had great flavors and was very soft and chewy.  Each candy was individually wrapped well.  None of the candies were stuck together, which did happen in the expensive version, Fralinger's.  Would highly recommend this candy!  I served it at a beach-themed party and everyone loved it!
# 3. Encrypted Similar Statement: gAAAAABnPd3KRoyMjxY0f-NUXQUoERTVrVlzQTjp4280AZ1Ir5szY7Bsgy3rWgOfpK0ynxupCyih3LVnydt4EHsbwXfKAbbekRIC4uZLaJEtb4gr4DBPHRVHIW1wvzllwaYp_f5O89hPzxFhYU4M11qANBFxnqGiwWDvpNy8DC0IM7DgkRGHqM9E3NNVLqMHkPChUgtT4RDUZaHjVwpr-OiDIGvnBeHzPzykJ8s0wgabwrEfKNHJMbLSaQTGUWQMwV10jF3FQVQA0CirAfJJ8GqllSTT5C4WKAsSTMDhd9uA0CgJ3CbJnz8w6drGhRLhoBUFxdKZnujQhxv448lhQ6OB5bYCxKezHuw4lyvUWKYybqANgm7t61aWaalO5nA6pisuuFITYSn665yrZB44YvVJySgbCyYaCB9N-KZvmaA8eoW9w4NlbaFvONQe8CTQ591K83HwnW1DwkCFxj9fTJb1kdXM9tTvy15po9z4s710SAzvpaT5CDRzFfHXliHbhOmN2ECUynhPH2VdWQdOsVcMCcpYYUl8A-To8eYAuUgAXOdhp0zwQsl1EG4tVjJqVGvCN-gqV0q-iMXSj-YKw5t46Hmp9ekiYXyjWielPX3fCkL_R1ndgTYsSA_I5ymgXM96cUIPSuE85uAH4aBJXW2UHSJCYpVwycDjoe10Mn65GFTadsbBsJb8oXtyisgSO4eoxihFjowikK2-7-CCFy2W0vP6SwcuPaRq2OgSAlpuo0xJv3gWFTs=
#    Decrypted Similar Statement: I don't know if it's the cactus or the tequila or just the unique combination of ingredients, but the flavour of this hot sauce makes it one of a kind!  We picked up a bottle once on a trip we were on and brought it back home with us and were totally blown away!  When we realized that we simply couldn't find it anywhere in our city we were bummed.<br /><br />Now, because of the magic of the internet, we have a case of the sauce and are ecstatic because of it.<br /><br />If you love hot sauce..I
# 4. Encrypted Similar Statement: gAAAAABnPd3KcMYN3XkHRRpHFKTM_UfVD6R8JDV-HuQGEJPuGWVWIt6TNTeVmMGjIkb2ruRC73FaFJG41ILy9UBSqFOufnrVupKaT49MiVYIczxuIj02bpfxUME-67LufTBc8DoudMrJiTiEbU7_Ha7Ar2xDb9k9ePmIqvC27o-v7wbd_gAG0lI723R_ohpAgykBWIxBiqr3-rNjpg4WvNOGeBjs2EHoOHJlz79GLXs1xQrigsBtivHRXnI7YZl6kMtbfV8uB-gz
#    Decrypted Similar Statement: This taffy is so good.  It is very soft and chewy.  The flavors are amazing.  I would definitely recommend you buying it.  Very satisfying!!
# 5. Encrypted Similar Statement: gAAAAABnPd3KxAchuGhu-SzwsLFyaXb_HDmjRc-6XT2zo4TlxSHglPs32KTBZ58vmfp66wHhOQnuuStotQ97uAEDNkKqWSo9StBaIZ5mX5-xsJcNO2Ii5ymkccT7fOpoQ5h34ftaGcra0QWAVkl4Oq630cngK9g25noJtLLvz6XEW2Ltuo2S-FWGCjzw_QRqM-LHFuX9y2S9SmASDZNxs2q3RzToQ0XYMp0GIUN18Ik0Fto-klhI_tLzCmUJVVKmWKof-qmtzOttgjS36ulZiXuPXPROWSoz6H7AT8dZ4e7J8xYNWXCqHrAn2LvueMXmsQo6mspTQS3uOjAbgWlQftHV_QHA8SuZz_ee0eH5LFoAShWROhDmxT9ZbfN2xzVOVYRDXA2uBbBG0tHn6Qr6_8uJrd4CxIicSUCbCdj3es-yVaWchDu7T8o=
#    Decrypted Similar Statement: I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
# 6. Encrypted Similar Statement: gAAAAABnPd3KipbhXzgVM45aHinGUTidxjkU5aqtceZ17Fqitia2qD9QIG5VpwIpemQ5oGdMeT6Hy5f4gYpP3GDoS1MYjk7gOn869VD6NFJ9JwY5UiHMn4LqDXKdcEbodzpvKRmb5MR7OaxltzVbPXQHDYXcWnDyog7L7oOw80jI4mxQx6_iHhjK-IKv3ysiT8pix4p897yLxxqc1KbNSNRzhJyEXZmJb8ZKTIzlCqmdgCWnuNjb9P_UGaoLHuOgcDZ4igcL1P3QNR_SRjyfTob6Oru_E6H5O7TJSDqTbE7Q4MDofl4RBk2Skh34MsIJHL-SpEsAGM1d3VmwgKXztnSt0vQgNPUl8sBDDrBPWzwBerS0Gwvz0pY6a4q1tRL6zgMVSFTPv3ncgtYn5aDPfYfc_nklSbzotASdC8yLBNLfGuR1azdwJIC9SgzNgxdi6cWI8FcXi1oeDIvYMB9ayoZKB9U786tm_6hpY8ssEB1JKS4Mr78twGao77GRlVgEfN9O1BxcD8fz
#    Decrypted Similar Statement: One of my boys needed to lose some weight and the other didn't.  I put this food on the floor for the chubby guy, and the protein-rich, no by-product food up higher where only my skinny boy can jump.  The higher food sits going stale.  They both really go for this food.  And my chubby boy has been losing about an ounce a week.
# 7. Encrypted Similar Statement: gAAAAABnPd3KFwJxL8I5Wm0Yct8lzPbnd7-NeFIMURrQDbUK662zWkG3Ssuh_7KcbboYR9iggFJU27ticJ47TM9OvQF9Qz3GY0L_TMes7y0x5VLiJERhUbtTw1ZEISIvboYl7sAFeQ6Y3ABKqzAydJievIsb8sVYvqGY2Rh2t0V3t9TrGEqGCT349ZJFJPhiFCO9tRMW2Acl0UQcOeY6UuU5ZR8W3-IIwC9s9xgo7CQlTRYWeaBHRVbQdNE-qMWGssiQdNa-7oy2
#    Decrypted Similar Statement: Right now I'm mostly just sprouting this so my cats can eat the grass. They love it. I rotate it around with Wheatgrass and Rye too
# 8. Encrypted Similar Statement: gAAAAABnPd3KNVx1O19hxq91P5ZH8D4j4geLg7GuucdFEA7RJMHfQdM--kWwhryxW6lq8KEu-bRFgS6DKx_T50alPvuBSN5d462RlWQTfzZGBFJwc5-y6BQIzsKXmyS0UlEFsqBI9LK_NfP3MbtOwUQaM9JFiEnz2ia7c_fIqq9Et71HK0QawFZHcZEEXjhunHBdtF65Xhz2C1MsU-XKJdCtiUMD5gYOniyHv2AEtDFtGVPOXqxOEJIDVAKG9x8lbpyloIUm37-xsJR5dD8lCYuEk0JeMziF3U3kMOKDvylN1gECQoqoTfJ7cnVGOoIhaITijrxVZfk4
#    Decrypted Similar Statement: Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 9. Encrypted Similar Statement: gAAAAABnPd3KpA5Bo4YwohOvFt-wx-OtqdePO1actscNe8HXZm6eH4Cg_77Lkvc9WNIBU1xsn3veovSBv8-nITg5AzmAgcYO3gZMYs1jeNT8D8WmYERqr8gb4ecpOGd_phdFUX0sxTak_yooOpuXSLb00b_hiGwmLQnv-QjUY3ie68lJKRCeu1Prv7ReG2sRU4nJ401ldq2BZEHKI6qCiYiigSjtaLiBxKZlrzNkIynp8eQBdDWqRGzODPfOuXOeZzTJbYNlhdrtzg10pB05JEd222SS4p-jQ9T6MTnA-9nKDYkQiYtCUDG3UMUXz2QAFx34iPY5nTHmewXllBIyb2Ee_IYRN-CJ4RgyyJCMZqUcX5JIApSKalpsdx_tyrHuYKpnlphAPRaLSSJTKwvrF2qCF1dNeJFtVmMECEhSXSPXm5Z22DBn5vuwaDIWxOHa5gGSulJ7XguplUBYqcHGBUE0OwcktXn97ZGShCiR1SCirI_9thNODQjYLeHrt5enMzwc6H4zx7oLjAFtyrv_JalbrmOu_3LjuwMy81s1gH8nieSAE0Dgq4CyjYHIKcK9ad6spPcSmqGGZyhbiKiWcmCc3dY5jC1i4Q==
#    Decrypted Similar Statement: My cats have been happily eating Felidae Platinum for more than two years. I just got a new bag and the shape of the food is different. They tried the new food when I first put it in their bowls and now the bowls sit full and the kitties will not touch the food. I've noticed similar reviews related to formula changes in the past. Unfortunately, I now need to find a new food that my cats will eat.
# 10. Encrypted Similar Statement: gAAAAABnPd3Kj9M1x7Rv2Bpt0ukJdypIEarHDro7VnVuYg1Jj-3tGZojVfVIRe6hex8_w2kE0u4KCZJeRnp7rY7KT8NodTFQNeRF9iZTexJgcPUQxEyvqCIoL5ejq2abz67iuZ5HRpgekx_x9oKGMrVELlG-xHr2A8eT6U3DMNeN71gKk6jGaCUH_ckvEG2ciH-fVNMbgoIFG5ery2aFae_IwNR8KJ0t2CU0bsPs0EMCgKsMVtjprU2y4oNgFFYxL5ULSaAXh9FERBc4hGFAGoh9t3ZIwk1iwcjG2-fHhocKQm5gE_6GMkiAsuU4SBzSMmsDuh1NelSeX863Obyv7SZXmKGii6GX62OV9mcB4tF7VGNedubSQ5lK1_qHWp1NEYeARE7C-E-11yPZKObmXHTB2NtjpeTqdfu5z4udgtrVYcVkO6ZypJwPSKzD4ycsqsWFA2eGT1TfqiRVWoLdXlDlGlfPIX-bJZi2C6mYeh5b-PATtu1MmnkQdJSGMRk8pAlMApa6gRTw8hK41iitYEuye6vGu7uQTlpyBTamt5_LASTNS8tM-Ra2Dmgm6dXds7yqUGjzVFu0uZLIUM__j73iVmxJ-slhUagZPubTG3ueTCwcTN-bRMQJRqQE-dSL17YhWOpyjDeoOyEH4xUPuYJRxYhf6sS4otpwTvpj_VEPLgGVsKjNOvxYGDwBjhipk-VZChuFEnPYdwNcc-Dg6xU_X38EdJl8LpjSdupGqEJghUNhjlqjewI=
#    Decrypted Similar Statement: This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with powdered sugar.  And it is a tiny mouthful of heaven.  Not too chewy, and very flavorful.  I highly recommend this yummy treat.  If you are familiar with the story of C.S. Lewis' "The Lion, The Witch, and The Wardrobe" - this is the treat that seduces Edmund into selling out his Brother and Sisters to t
# 11. Encrypted Similar Statement: gAAAAABnPd3KTbqREhITtwpIoS5ZqCl8V-uCyXtY4o63x_ByKfkhiGl69OJquvH267k2_PryZ3pfQNMtF2X3uw-U4Ob_L_QwxrtuN--HpWecNoqsvbQKoHk5g3KEbSlh-CKLPMfrFbLNjV2vDfwfW1FaNWl5rR8Gtmi9NqJJXCVtJBRyQP0ptjVzcfHwRRGGjU80WG4zrks8chlqBjb-2f6m1gEeSx_1SOsgjQcY_GYClIYzeypgZOujg2mwF5ZNbvTak-i0cetUypsXfqLV3nUv1PW1HNcHIpGOL2jniW_ub_lSVbwW6yx_dYAd0NrJB7yB8W0V3ZDFlmF3Gau7QQwsM0KoKtqWBjQ_nzDCC-QmbuX-0udPAQE=
#    Decrypted Similar Statement: If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The flavor is very medicinal.
# 12. Encrypted Similar Statement: gAAAAABnPd3KezYXurZBqflWYHEzg0w35buHbXTvHD-17CLU56fKk4iHCiAkl1XKcLj_cc1o7PfjeCwjLJE-88Our3dmzgD_I5L4gBW7lFlmq5yq1A5H3EqnpY1kyb3wDWm_3grmsUEst5cVBaD1ORUvxHasflewaR4JaECI2maSUgVgqyhzuBESM8zkgXpi7zTDNOYf7prYwBXhaplj88mv6SxII7ZO-Q==
#    Decrypted Similar Statement: good flavor! these came securely packed... they were fresh and delicious! i love these Twizzlers!
# 13. Encrypted Similar Statement: gAAAAABnPd3KEN4afBRjCoSosbRzlpkPDopOYx5383MUIH4JxV4D2qQiQwirx0RW3zR5uyXXldupVfA8AREBMbe7BwW9iDqOOZagCwK7A-kMjAZHXkz4kicr4U0y_E4GhMB6rWS6oJtfceX6g4HVxLan3kZoe2lAUCulyS6hwLhPYrweUNRnCXxTlHaLdBqWsP8j5zJzpleR2zTt_K0vypHvhuuetgcSh240j_sAL0LVfw-mXGkfLRQ=
#    Decrypted Similar Statement: The Strawberry Twizzlers are my guilty pleasure - yummy. Six pounds will be around for a while with my son and I.
# 14. Encrypted Similar Statement: gAAAAABnPd3KOfm4c2ZuKvMLhScbY_cdOOgHB2ImHLbAnkpmI8UIiI5VsWBCPEbiyEQzhi2bDyXHLbuFZhSF0C1e_umLiZm-QTkvoic8VQzzszoLlj0p2q4rtQ69V-RzfqT4pZxu8IXz9Iwdy_bK9KQuZkywVziCi_PyqV2yyptlwQ813wYjk-q-UQIp0POIpoLHzjrOXgkqLqCQPZ1syh-fjM2R2rb-8GmsBpQ7DdFHBqbNtywaAUcA5ykBeCOV2LDFrPUL_Yws
#    Decrypted Similar Statement: This is a very healthy dog food. Good for their digestion. Also good for small puppies. My dog eats her required amount at every feeding.
# 15. Encrypted Similar Statement: gAAAAABnPd3KlfQj47dfVTcLoPQi-ke2vYTdhHAKR8V0V8G0qSTrAWwpHA_7krGQgQ-YaCxa7ooQCXCvsnm5c3kKlYlP9DO6RxBmBmKGiTk5v8OWiRlyOb3DCaqzsDO1Xi8c6Jh3y4x41wmfDHzdcy_DYOu4XY6JF4eKbKDqkgWOvJnozRBn_yQb081duyOPzXnX9e-nn_F0-PRbwFM7hlGtZhK6tHxQ7WMEoIohGtTItbJa94XEJP2Bqbcgd6AO0RY-usjKXRQx
#    Decrypted Similar Statement: Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
